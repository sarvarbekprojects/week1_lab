# %% [markdown]
# <a href="https://colab.research.google.com/github/sarvarbekprojects/week1_lab/blob/main/example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Please update the information, and submit your work

# %%
my_name = "Sarvarbek Qobilov "

# %%
my_enrollment_number = "A85204925040"

# %%
my_hobby = "Coding, Playing football"

# %%
print("Hello, my name is {}, and my my enrollment number is {}. I like {}.".format(my_name, my_enrollment_number, my_hobby))
# Out:
# Hello, my name is Sarvarbek Qobilov , and my my enrollment number is A85204925040. I like Coding, Playing football.
